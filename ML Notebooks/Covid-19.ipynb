# %%
import pandas as pd

# %%
total=pd.read_csv(r'C:\Users\KARTHIK SURINENI\.idlerc\Downloads\convertcsv.csv')

# %%
total.columns
# Out:
# Index(['states_daily/an', 'states_daily/ap', 'states_daily/ar',
#        'states_daily/as', 'states_daily/br', 'states_daily/ch',
#        'states_daily/ct', 'states_daily/date', 'states_daily/dd',
#        'states_daily/dl', 'states_daily/dn', 'states_daily/ga',
#        'states_daily/gj', 'states_daily/hp', 'states_daily/hr',
#        'states_daily/jh', 'states_daily/jk', 'states_daily/ka',
#        'states_daily/kl', 'states_daily/la', 'states_daily/ld',
#        'states_daily/mh', 'states_daily/ml', 'states_daily/mn',
#        'states_daily/mp', 'states_daily/mz', 'states_daily/nl',
#        'states_daily/or', 'states_daily/pb', 'states_daily/py',
#        'states_daily/rj', 'states_daily/sk', 'states_daily/status',
#        'states_daily/tg', 'states_daily/tn', 'states_daily/tr',
#        'states_daily/tt', 'states_daily/un', 'states_daily/up',
#        'states_daily/ut', 'states_daily/wb'],
#       dtype='object')

# %%
confirmed=pd.DataFrame(columns=total.columns)

# %%
i=0
while i<=(len(total['states_daily/tt'])):
    confirmed=confirmed.append(total[i:i+1])
    i=i+3

# %%
confirmed.head()
# Out:
#    states_daily/an states_daily/ap states_daily/ar states_daily/as  \
# 0                0               1               0               0
# 3                0               0               0               0
# 6                0               0               0               0
# 9                0               0               0               0
# 12               0               0               0               0
#
#    states_daily/br states_daily/ch states_daily/ct states_daily/date  \
# 0                0               0               0         14-Mar-20
# 3                0               0               0         15-Mar-20
# 6                0               0               0         16-Mar-20
# 9                0               0               0         17-Mar-20
# 12               0               0               0         18-Mar-20
#
#    states_daily/dd states_daily/dl  ... states_daily/sk states_daily/status  \
# ...

# %%
confirmed.to_csv('D:/D/prgrms/Confirmed3.csv',index=False)

# %%
confirmed=pd.read_csv(r'D:\D\prgrms\Confirmed3.csv')
confirmed1=pd.read_csv(r'D:\D\prgrms\Confirmed2.csv')

# %%
confirmed.columns=confirmed1.columns
b=confirmed.columns

# %%
new=confirmed

# %%
for i in range(2,len(b)):
    a=list(confirmed[b[i]])
    for j in range(1,len(a)):
        a[j]=a[j]+a[j-1]
    #print(a[i],b[i])
    new[b[i]]=a

# %%
for i in range(2,len(b)):
    a=list(new[b[i]])
    for j in range(1,len(a)):
        if a[j]<a[j-1]:
            a[j-1]=a[j]
            print(b[i],j)
    new[b[i]]=a
# Out:
# Andaman And Nicobar 14
# Andaman And Nicobar 15
# Andaman And Nicobar 17
# Andaman And Nicobar 26
# Andaman And Nicobar 36
# Andaman And Nicobar 42
# Andaman And Nicobar 43
# Andaman And Nicobar 90
# Andaman And Nicobar 93
# Andaman And Nicobar 95
# Andaman And Nicobar 98
# Andaman And Nicobar 100
# Andhra Pradesh 1
# Andhra Pradesh 6
# Andhra Pradesh 8
# Andhra Pradesh 12
# Andhra Pradesh 15
# Andhra Pradesh 19
# Andhra Pradesh 20
# Andhra Pradesh 23
# Andhra Pradesh 24
# Andhra Pradesh 26
# Andhra Pradesh 29
# Andhra Pradesh 32
# Andhra Pradesh 33
# Andhra Pradesh 35
# Andhra Pradesh 38
# Andhra Pradesh 41
# Andhra Pradesh 42
# Andhra Pradesh 44
# Andhra Pradesh 46
# Andhra Pradesh 47
# Andhra Pradesh 48
# Andhra Pradesh 50
# Andhra Pradesh 53
# Andhra Pradesh 54
# Andhra Pradesh 55
# Andhra Pradesh 56
# Andhra Pradesh 58
# Andhra Pradesh 60
# Andhra Pradesh 63
# Andhra Pradesh 64
# Andhra Pradesh 68
# Andhra Pradesh 70
# Andhra Pradesh 73
# Andhra Pradesh 75
# Andhra Pradesh 76
# ...

# %%
new.to_csv('D:/D/prgrms/Confirmed3.csv',index=False)

# %%
from bs4 import BeautifulSoup
import re

# %%
new=pd.read_csv(r'D:\D\prgrms\Confirmed3.csv')

# %%
date=list(new['Date'])
date
# Out:
# ['14-Mar-20',
#  '15-Mar-20',
#  '16-Mar-20',
#  '17-Mar-20',
#  '18-Mar-20',
#  '19-Mar-20',
#  '20-Mar-20',
#  '21-Mar-20',
#  '22-Mar-20',
#  '23-Mar-20',
#  '24-Mar-20',
#  '25-Mar-20',
#  '26-Mar-20',
#  '27-Mar-20',
#  '28-Mar-20',
#  '29-Mar-20',
#  '30-Mar-20',
#  '31-Mar-20',
#  '01-Apr-20',
#  '02-Apr-20',
#  '03-Apr-20',
#  '04-Apr-20',
#  '05-Apr-20',
#  '06-Apr-20',
#  '07-Apr-20',
#  '08-Apr-20',
#  '09-Apr-20',
#  '10-Apr-20',
#  '11-Apr-20',
#  '12-Apr-20',
#  '13-Apr-20',
#  '14-Apr-20',
#  '15-Apr-20',
#  '16-Apr-20',
#  '17-Apr-20',
#  '18-Apr-20',
#  '19-Apr-20',
#  '20-Apr-20',
#  '21-Apr-20',
#  '22-Apr-20',
#  '23-Apr-20',
#  '24-Apr-20',
#  '25-Apr-20',
#  '26-Apr-20',
#  '27-Apr-20',
#  '28-Apr-20',
#  '29-Apr-20',
#  '30-Apr-20',
#  '01-May-20',
#  '02-May-20',
#  '03-May-20',
#  '04-May-20',
#  '05-May-20',
#  '06-May-20',
#  '07-May-20',
#  '08-May-20',
#  '09-May-20',
#  '10-May-20',
#  '11-May-20',
#  '12-May-20',
#  '13-May-20',
#  '14-May-20',
# ...

# %%
def clean1(da):
    da=BeautifulSoup(da,'lxml').get_text()
    da=re.sub(r'-Mar[A-Za-z0-9.-]+',' 3',da)
    da=re.sub(r'-A[A-Za-z0-9.-]+',' 4',da)
    da=re.sub(r'-May[A-Za-z0-9.-]+',' 5',da)
    da=re.sub(r'-J[A-Za-z0-9.-]+',' 6',da)
    mo=da.split()
    if mo[1]=='3':
        mo[0]=int(mo[0])+60
    if mo[1]=='4':
        mo[0]=int(mo[0])+91
    if mo[1]=='5':
        mo[0]=int(mo[0])+121
    if mo[1]=='6':
        mo[0]=int(mo[0])+152
    return mo[0]

# %%
for i in range(len(date)):
    date[i]=clean1(date[i])

# %%
new['Date']=date

# %%
new.to_csv('D:/D/prgrms/Confirmed3.csv',index=False)

# %%
import matplotlib.pyplot as plt

# %%
fig=plt.plot(new['Date'],new['Telangana'],color='red')

#fig=plt.figure(new['Date'],new['Telangana'],color='red')
plt.savefig('C:/Users/KARTHIK SURINENI/Plots/Telangana.png')
plt.show()
fig

# %%
new.describe()
# Out:
#              Date  Andaman And Nicobar  Andhra Pradesh  Arunachal Pradesh  \
# count   99.000000            99.000000       99.000000          99.000000
# mean   123.000000           806.727273    47088.939394         151.939394
# std     28.722813           740.247584    56145.195059         324.747683
# min     74.000000             0.000000        1.000000           0.000000
# 25%     98.500000           120.500000     1841.000000           6.500000
# 50%    123.000000           621.000000    21800.000000          31.000000
# 75%    147.500000          1429.500000    77322.500000          59.000000
# max    172.000000          2333.000000   203580.000000        1548.000000
#
#               Assam          Bihar    Chandigarh   Chattisgarh  Daman & Diu  \
# count     99.000000      99.000000     99.000000     99.000000         99.0
# mean    8907.252525   28317.323232   3321.252525   4238.292929          0.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
from sklearn import linear_model
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn import linear_model
from sklearn.metrics import mean_absolute_error
a=linear_model.LinearRegression()
new1=np.array(new['Date']).reshape(-1,1)
x1=(np.arange(65,165)).reshape(-1,1)

# %%
mo=PolynomialFeatures(degree=6)
new2=mo.fit_transform(new1,new['Total'])
x=mo.transform(x1)
a.fit(new2,new['Total'])
y=a.predict(x)
#print(mean_absolute_error(new['Total'],y))
#print(y)
plt.plot(new['Date'],new['Total'],color='blue',label='Original Count')
plt.plot(x1,y,color='red',label='Predicted Count')
plt.grid()
plt.xlabel('Day')
plt.legend(loc='upper left')
plt.savefig('C:/Users/KARTHIK SURINENI/Plots/India.png')
plt.show()

# %%
'''for i in range(1,104):
    print(i+61,new['Total'][i]-new['Total'][i-1],y[i]-y[i-1])
#print(len(new['Total']))
#print(new['Total'][104],y[99])
print(new['Total'][104],y[104])'''
# Out:
# "for i in range(1,104):\n    print(i+61,new['Total'][i]-new['Total'][i-1],y[i]-y[i-1])\n#print(len(new['Total']))\n#print(new['Total'][104],y[99])\nprint(new['Total'][104],y[104])"

# %%
from sklearn import linear_model
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn import linear_model
from sklearn.metrics import mean_absolute_error
a=linear_model.LinearRegression()
new1=np.array(new['Date']).reshape(-1,1)

# %%
x1=(np.arange(61,165)).reshape(-1,1)
mo=PolynomialFeatures(degree=4)
new2=mo.fit_transform(new1,new['Telangana'])
x=mo.transform(x1)
a.fit(new2,new['Telangana'])
y=a.predict(x)
#print(mean_absolute_error(new['Total'],y))
#print(y)
plt.plot(new['Date'],new['Telangana'],color='blue',label='Original Count')
plt.plot(x1,y,color='red',label='Predicted Count')
plt.grid()
plt.xlabel('Day')
plt.legend(loc='upper left')
plt.savefig('C:/Users/KARTHIK SURINENI/Plots/Telangana.png')
plt.show()

# %%
from sklearn import linear_model
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn import linear_model
from sklearn.metrics import mean_absolute_error
a=linear_model.LinearRegression()
new1=np.array(new['Date']).reshape(-1,1)

# %%
x1=(np.arange(61,255)).reshape(-1,1)
mo=PolynomialFeatures(degree=4)
new2=mo.fit_transform(new1,new['WestBengal'])
x=mo.transform(x1)
a.fit(new2,new['WestBengal'])
y=a.predict(x)
#print(mean_absolute_error(new['Total'],y))
#print(y)
plt.plot(new['Date'],new['WestBengal'],color='blue')
plt.plot(x1,y,color='red')
plt.show()

# %%
x1=(np.arange(61,185)).reshape(-1,1)
mo=PolynomialFeatures(degree=4)
new2=mo.fit_transform(new1,new['Uttarakand'])
x=mo.transform(x1)
a.fit(new2,new['Uttarakand'])
y=a.predict(x)
#print(mean_absolute_error(new['Total'],y))
#print(y)
plt.plot(new['Date'],new['Uttarakand'],color='blue')
plt.plot(x1,y,color='red')
plt.show()

# %%
x1=(np.arange(61,185)).reshape(-1,1)
mo=PolynomialFeatures(degree=4)
new2=mo.fit_transform(new1,new['UttarPradesh'])
x=mo.transform(x1)
a.fit(new2,new['UttarPradesh'])
y=a.predict(x)
#print(mean_absolute_error(new['Total'],y))
#print(y)
plt.plot(new['Date'],new['UttarPradesh'],color='blue')
plt.plot(x1,y,color='red')
plt.show()

# %%
x1=(np.arange(61,185)).reshape(-1,1)
mo=PolynomialFeatures(degree=3)
new2=mo.fit_transform(new1,new['Tripura'])
x=mo.transform(x1)
a.fit(new2,new['Tripura'])
y=a.predict(x)
#print(mean_absolute_error(new['Total'],y))
#print(y)
plt.plot(new['Date'],new['Tripura'],color='blue')
plt.plot(x1,y,color='red')
plt.show()

# %%
x1=(np.arange(61,185)).reshape(-1,1)
mo=PolynomialFeatures(degree=4)
new2=mo.fit_transform(new1,new['TamilNadu'])
x=mo.transform(x1)
a.fit(new2,new['TamilNadu'])
y=a.predict(x)
#print(mean_absolute_error(new['Total'],y))
#print(y)
plt.plot(new['Date'],new['TamilNadu'],color='blue')
plt.plot(x1,y,color='red')
plt.show()

# %%
x1=(np.arange(61,185)).reshape(-1,1)
mo=PolynomialFeatures(degree=4)
new2=mo.fit_transform(new1,new['Sikkim'])
x=mo.transform(x1)
a.fit(new2,new['Sikkim'])
y=a.predict(x)
#print(mean_absolute_error(new['Total'],y))
#print(y)
plt.plot(new['Date'],new['Sikkim'],color='blue')
plt.plot(x1,y,color='red')
plt.show()

# %%
x1=(np.arange(61,185)).reshape(-1,1)
mo=PolynomialFeatures(degree=4)
new2=mo.fit_transform(new1,new['Rajasthan'])
x=mo.transform(x1)
a.fit(new2,new['Rajasthan'])
y=a.predict(x)
#print(mean_absolute_error(new['Total'],y))
#print(y)
plt.plot(new['Date'],new['Rajasthan'],color='blue')
plt.plot(x1,y,color='red')
plt.show()

# %%
x1=(np.arange(61,185)).reshape(-1,1)
mo=PolynomialFeatures(degree=3)
new2=mo.fit_transform(new1,new['Pondicherry'])
x=mo.transform(x1)
a.fit(new2,new['Pondicherry'])
y=a.predict(x)
#print(mean_absolute_error(new['Total'],y))
#print(y)
plt.plot(new['Date'],new['Pondicherry'],color='blue')
plt.plot(x1,y,color='red')
plt.show()

# %%
x1=(np.arange(61,185)).reshape(-1,1)
mo=PolynomialFeatures(degree=2)
new2=mo.fit_transform(new1,new['Punjab'])
x=mo.transform(x1)
a.fit(new2,new['Punjab'])
y=a.predict(x)
#print(mean_absolute_error(new['Total'],y))
#print(y)
plt.plot(new['Date'],new['Punjab'],color='blue')
plt.plot(x1,y,color='red')
plt.show()

# %%
x1=(np.arange(61,185)).reshape(-1,1)
mo=PolynomialFeatures(degree=4)
new2=mo.fit_transform(new1,new['Orissa'])
x=mo.transform(x1)
a.fit(new2,new['Orissa'])
y=a.predict(x)
#print(mean_absolute_error(new['Total'],y))
#print(y)
plt.plot(new['Date'],new['Orissa'],color='blue')
plt.plot(x1,y,color='red')
plt.show()

# %%
x1=(np.arange(61,185)).reshape(-1,1)
mo=PolynomialFeatures(degree=4)
new2=mo.fit_transform(new1,new['Nagaland'])
x=mo.transform(x1)
a.fit(new2,new['Nagaland'])
y=a.predict(x)
#print(mean_absolute_error(new['Total'],y))
#print(y)
plt.plot(new['Date'],new['Nagaland'],color='blue')
plt.plot(x1,y,color='red')
plt.show()

# %%
x1=(np.arange(61,285)).reshape(-1,1)
mo=PolynomialFeatures(degree=5)
new2=mo.fit_transform(new1,new['Mizoram'])
x=mo.transform(x1)
a.fit(new2,new['Mizoram'])
y=a.predict(x)
#print(mean_absolute_error(new['Total'],y))
#print(y)
plt.plot(new['Date'],new['Mizoram'],color='blue')
plt.plot(x1,y,color='red')
plt.show()

# %%
x1=(np.arange(61,185)).reshape(-1,1)
mo=PolynomialFeatures(degree=3)
new2=mo.fit_transform(new1,new['Madhya Pradesh'])
x=mo.transform(x1)
a.fit(new2,new['Madhya Pradesh'])
y=a.predict(x)
#print(mean_absolute_error(new['Total'],y))
#print(y)
plt.plot(new['Date'],new['Madhya Pradesh'],color='blue')
plt.plot(x1,y,color='red')
plt.show()

# %%
x1=(np.arange(61,185)).reshape(-1,1)
mo=PolynomialFeatures(degree=4)
new2=mo.fit_transform(new1,new['Manipur'])
x=mo.transform(x1)
a.fit(new2,new['Manipur'])
y=a.predict(x)
#print(mean_absolute_error(new['Total'],y))
#print(y)
plt.plot(new['Date'],new['Manipur'],color='blue')
plt.plot(x1,y,color='red')
plt.show()

# %%
for i in range(1,104):
    print(i+61,new['Manipur'][i]-new['Manipur'][i-1],y[i]-y[i-1])
#print(len(new['Total']))
#print(new['Total'][104],y[99])
print(new['Manipur'][104],y[104])
# Out:
# 62 0 -6.526970296604304
# 63 0 -5.795189942959951
# 64 0 -5.105531443206928
# 65 0 -4.456952252041447
# 66 0 -3.8484098241669926
# 67 0 -3.2788616142688625
# 68 0 -2.747265077064185
# 69 0 -2.25257766723189
# 70 0 -1.7937568394791015
# 71 0 -1.3697600484974828
# 72 0 -0.9795447489932485
# 73 0 -0.6220683956562425
# 74 0 -0.2962884431881321
# 75 0 -0.001162346285127569
# 76 0 0.26435244036019867
# 77 0 0.5012984620407224
# 78 0 0.7107182640620522
# 79 0 0.8936543917352537
# 80 0 1.0511493903559312
# 81 0 1.184245805216051
# 82 0 1.2939861816357734
# 83 0 1.3814130649152503
# 84 1 1.4475690003419004
# 85 0 1.4934965332358843
# 86 0 1.5202382088900777
# 87 0 1.5288365726082702
# 88 0 1.5203341696978896
# 89 0 1.4957735454499925
# 90 0 1.4561972451811016
# 91 0 1.4026478141840926
# 92 0 1.336167797760936
# 93 1 1.2577997412226978
# 94 0 1.1685861898658914
# 95 0 1.0695696889924875
# 96 0 0.9617927839044569
# 97 0 0.8462980199128651
# 98 0 0.72412794230695
# 99 0 0.5963250963941391
# ...

# %%
#x1

# %%
a.predict(mo.transform((np.array(245)).reshape(-1,1)))
# Out:
# array([2318870.3587598])

# %% [markdown]
# for i in range(1,len(new['Telangana'])):
#     print(new['Telangana'][i],y[i])

# %%
states=pd.DataFrame(columns=new.columns)
states.to_csv('D:/D/prgrms/states.csv')
